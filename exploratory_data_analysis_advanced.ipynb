# %% [markdown]
# ## Summary of key insights
#
# - Most features are categorical (all but price and sale date), many of them take a huge number of different values, many values appearing only once, which will make prediction difficult without some pooling
#
# - The price distribution is very right skewed, so that the log-price is more convenient to study.
#
# - Almost all sales were done after 1985. A very strong inflation is visible over time since 1985, stronger than general consumer index inflation. Perhaps a feature "inflation corrected price" is needed.
#
# - Cellos are the most valued, followed by violins and viols and bows. Several instrument types are very rare.
#
# - Among makers totalling over 50 sales, the 10 most expansive and the 10 least expansive display a spectacularly different price distribution. The most expensive are concentrated in Italy.
#
# - In general, the more ancient the instrument, the more valuable. Yet 1500 makers lack the date, representing 6k sales, which is a significant caveat. Ideally, we could write some script to fetch their date from some other database on internet.

# %% [markdown]
# ## Importation of packages and data frames

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
sales=pd.read_csv("price_adj_w_all_features.csv")
# Out:
# C:\Users\Pierre\AppData\Local\Temp\ipykernel_11440\3119891546.py:1: DtypeWarning: Columns (0: auction_house, 1: lot) have mixed types. Specify dtype option on import or set low_memory=False.
#   sales=pd.read_csv("price_adj_w_all_features.csv")

# %%
sales.isna().sum()
# Out:
# maker_id                    0
# maker_name                  0
# type                        0
# city_maker              17083
# auction_house            4282
# sale_date                   0
# lot                      4282
# usd                         0
# gbp                         0
# eur                     18245
# bold_currency               0
# Year                        0
# Month                       0
# Day                         0
# cpi_usd                     0
# cpi_gbp                     0
# cpi_eur                 14798
# gbp_usd_x                   0
# eur_usd                 18285
# price_usd_real              0
# SP500_real                  0
# SP500_30d_ret               0
# SP500_90d_ret               0
# SP500_252d_ret              0
# SP500_vol_30d               0
# SP500_vol_90d               0
# SP500_vol_252d              0
# SP500_ma50                  0
# SP500_ma200                 0
# SP500_trend_ratio           0
# gbp_usd_y                 635
# gbp_90d_change            635
# gbp_vol_30d               635
# 10y_yield_pc                0
# 10y_yield_90d_change        0
# MCI                         0
# real_price_gold             0
# country_iso1            17224
# admin1_name             17224
# admin2_name             20865
# candidate_count         17083
# is_ambiguous                0
# maker_name_maker            0
# role                     2187
# date                     6091
# maker_last_name             0
# birth_cent               6091
# dtype: int64

# %% [markdown]
# There are 11 columns in the original Taisio-Cozio data set, many more with the feature engineering; maker_id and maker_name are probably the same thing, they identify a maker. The bold currency (usd, gbp or eur) indicates in which currency the sale was made. It is often missing. We'll have to look at duplicates.

# %%
sales[sales.duplicated()]
#there are no exact duplicates
# Out:
# Empty DataFrame
# Columns: [maker_id, maker_name, type, city_maker, auction_house, sale_date, lot, usd, gbp, eur, bold_currency, Year, Month, Day, cpi_usd, cpi_gbp, cpi_eur, gbp_usd_x, eur_usd, price_usd_real, SP500_real, SP500_30d_ret, SP500_90d_ret, SP500_252d_ret, SP500_vol_30d, SP500_vol_90d, SP500_vol_252d, SP500_ma50, SP500_ma200, SP500_trend_ratio, gbp_usd_y, gbp_90d_change, gbp_vol_30d, 10y_yield_pc, 10y_yield_90d_change, MCI, real_price_gold, country_iso1, admin1_name, admin2_name, candidate_count, is_ambiguous, maker_name_maker, role, date, maker_last_name, birth_cent]
# Index: []
#
# [0 rows x 47 columns]

# %%
sales[sales.duplicated(['maker_id','type','sale_date','usd'],keep=False)]
# Out:
#        maker_id                                  maker_name        type  \
# 625         175                    Fétique, Victor François  Violin Bow
# 626         175                    Fétique, Victor François  Violin Bow
# 634         944                                 Rau, August  Violin Bow
# 657         647                     Sartory, Eugène Nicolas  Violin Bow
# 658         647                     Sartory, Eugène Nicolas  Violin Bow
# ...         ...                                         ...         ...
# 48234       951  Bernardel, Auguste Sébastien Philippe père      Violin
# 50125      1309                         Martin, Jean-Joseph  Violin Bow
# 50126      1309                         Martin, Jean-Joseph  Violin Bow
# 52282       647                     Sartory, Eugène Nicolas  Violin Bow
# 52298       647                     Sartory, Eugène Nicolas  Violin Bow
#
#            city_maker   auction_house   sale_date  lot      usd           gbp  \
# 625             Paris       Sotheby's  1983-04-07   73   2150.0   5086.233616
# 626             Paris       Sotheby's  1983-04-07   82   2150.0   5086.233616
# 634    Markneukirchen       Sotheby's  1983-04-07  504    182.0    430.373614
# 657             Paris       Sotheby's  1983-04-07   25   2812.0   6651.228575
# 658             Paris       Sotheby's  1983-04-07   34   2812.0   6651.228575
# ...               ...             ...         ...  ...      ...           ...
# 48234           Paris  Vichy-Enchères  2022-12-01  270  33929.0  27608.000000
# 50125           Paris             NaN  2024-03-22  NaN   4236.0   3474.893617
# 50126             NaN             NaN  2024-03-22  NaN   4236.0   3474.893617
# 52282             NaN             NaN  2025-10-28  NaN  30270.0  22800.000000
# 52298           Paris             NaN  2025-10-28  NaN  30270.0  22800.000000
#
#                 eur  ... country_iso1    admin1_name  admin2_name  \
# 625             NaN  ...           FR  Île-de-France        Paris
# 626             NaN  ...           FR  Île-de-France        Paris
# 634             NaN  ...           DE         Saxony          NaN
# 657             NaN  ...           FR  Île-de-France        Paris
# 658             NaN  ...           FR  Île-de-France        Paris
# ...             ...  ...          ...            ...          ...
# 48234  34634.191835  ...           FR  Île-de-France        Paris
# 50125   3916.000000  ...           FR  Île-de-France        Paris
# 50126   3916.000000  ...          NaN            NaN          NaN
# 52282  26027.000000  ...          NaN            NaN          NaN
# 52298  26027.000000  ...           FR  Île-de-France        Paris
#
#        candidate_count  is_ambiguous  \
# 625               59.0          True
# 626               59.0          True
# 634                2.0          True
# 657               59.0          True
# 658               59.0          True
# ...                ...           ...
# 48234             59.0          True
# 50125             59.0          True
# 50126              NaN         False
# 52282              NaN         False
# 52298             59.0          True
#
#                                  maker_name_maker          role       date  \
# 625                      Fétique, Victor François     Bow maker  1872-1933
# 626                      Fétique, Victor François     Bow maker  1872-1933
# 634                                   Rau, August     Bow maker  1866-1951
# 657                       Sartory, Eugène Nicolas     Bow maker  1871-1946
# 658                       Sartory, Eugène Nicolas     Bow maker  1871-1946
# ...                                           ...           ...        ...
# 48234  Bernardel, Auguste Sébastien Philippe père  Violin maker  1798-1870
# 50125                         Martin, Jean-Joseph     Bow maker  1837-1910
# 50126                         Martin, Jean-Joseph     Bow maker  1837-1910
# 52282                     Sartory, Eugène Nicolas     Bow maker  1871-1946
# 52298                     Sartory, Eugène Nicolas     Bow maker  1871-1946
#
#        maker_last_name  birth_cent
# 625            Fétique        19.0
# 626            Fétique        19.0
# 634                Rau        19.0
# 657            Sartory        19.0
# 658            Sartory        19.0
# ...                ...         ...
# 48234        Bernardel        18.0
# 50125           Martin        19.0
# 50126           Martin        19.0
# 52282          Sartory        19.0
# 52298          Sartory        19.0
#
# [1910 rows x 47 columns]

# %% [markdown]
# We do seem to see 3 pairs of duplicates here, but the rows with lots 255A and 255AA are probably genuinely different (a sublot in the world of auction house). We'll look for sales which in only differ in the lot being "-" instead of a proper values and consider them duplicates.

# %%
cols = ['sale_date', 'maker_id', 'type', 'usd', 'gbp', 'auction_house']
mask_dash = sales['lot'] == '-'
has_twin = sales[mask_dash].apply(
    lambda r: ((sales[cols] == r[cols]).all(axis=1) & (sales['lot'] != '-')).any(),
    axis=1
)
sales = sales.drop(index=sales[mask_dash][has_twin].index)

# %%
len(sales)
# we lost 188 rows, kind of negligible
# Out:
# 52356

# %%
sales[sales.duplicated(['maker_id','type','sale_date','usd'],keep=False)]
# Out:
#        maker_id                                  maker_name        type  \
# 625         175                    Fétique, Victor François  Violin Bow
# 626         175                    Fétique, Victor François  Violin Bow
# 634         944                                 Rau, August  Violin Bow
# 657         647                     Sartory, Eugène Nicolas  Violin Bow
# 658         647                     Sartory, Eugène Nicolas  Violin Bow
# ...         ...                                         ...         ...
# 48234       951  Bernardel, Auguste Sébastien Philippe père      Violin
# 50125      1309                         Martin, Jean-Joseph  Violin Bow
# 50126      1309                         Martin, Jean-Joseph  Violin Bow
# 52282       647                     Sartory, Eugène Nicolas  Violin Bow
# 52298       647                     Sartory, Eugène Nicolas  Violin Bow
#
#            city_maker   auction_house   sale_date  lot      usd           gbp  \
# 625             Paris       Sotheby's  1983-04-07   73   2150.0   5086.233616
# 626             Paris       Sotheby's  1983-04-07   82   2150.0   5086.233616
# 634    Markneukirchen       Sotheby's  1983-04-07  504    182.0    430.373614
# 657             Paris       Sotheby's  1983-04-07   25   2812.0   6651.228575
# 658             Paris       Sotheby's  1983-04-07   34   2812.0   6651.228575
# ...               ...             ...         ...  ...      ...           ...
# 48234           Paris  Vichy-Enchères  2022-12-01  270  33929.0  27608.000000
# 50125           Paris             NaN  2024-03-22  NaN   4236.0   3474.893617
# 50126             NaN             NaN  2024-03-22  NaN   4236.0   3474.893617
# 52282             NaN             NaN  2025-10-28  NaN  30270.0  22800.000000
# 52298           Paris             NaN  2025-10-28  NaN  30270.0  22800.000000
#
#                 eur  ... country_iso1    admin1_name  admin2_name  \
# 625             NaN  ...           FR  Île-de-France        Paris
# 626             NaN  ...           FR  Île-de-France        Paris
# 634             NaN  ...           DE         Saxony          NaN
# 657             NaN  ...           FR  Île-de-France        Paris
# 658             NaN  ...           FR  Île-de-France        Paris
# ...             ...  ...          ...            ...          ...
# 48234  34634.191835  ...           FR  Île-de-France        Paris
# 50125   3916.000000  ...           FR  Île-de-France        Paris
# 50126   3916.000000  ...          NaN            NaN          NaN
# 52282  26027.000000  ...          NaN            NaN          NaN
# 52298  26027.000000  ...           FR  Île-de-France        Paris
#
#        candidate_count  is_ambiguous  \
# 625               59.0          True
# 626               59.0          True
# 634                2.0          True
# 657               59.0          True
# 658               59.0          True
# ...                ...           ...
# 48234             59.0          True
# 50125             59.0          True
# 50126              NaN         False
# 52282              NaN         False
# 52298             59.0          True
#
#                                  maker_name_maker          role       date  \
# 625                      Fétique, Victor François     Bow maker  1872-1933
# 626                      Fétique, Victor François     Bow maker  1872-1933
# 634                                   Rau, August     Bow maker  1866-1951
# 657                       Sartory, Eugène Nicolas     Bow maker  1871-1946
# 658                       Sartory, Eugène Nicolas     Bow maker  1871-1946
# ...                                           ...           ...        ...
# 48234  Bernardel, Auguste Sébastien Philippe père  Violin maker  1798-1870
# 50125                         Martin, Jean-Joseph     Bow maker  1837-1910
# 50126                         Martin, Jean-Joseph     Bow maker  1837-1910
# 52282                     Sartory, Eugène Nicolas     Bow maker  1871-1946
# 52298                     Sartory, Eugène Nicolas     Bow maker  1871-1946
#
#        maker_last_name  birth_cent
# 625            Fétique        19.0
# 626            Fétique        19.0
# 634                Rau        19.0
# 657            Sartory        19.0
# 658            Sartory        19.0
# ...                ...         ...
# 48234        Bernardel        18.0
# 50125           Martin        19.0
# 50126           Martin        19.0
# 52282          Sartory        19.0
# 52298          Sartory        19.0
#
# [1550 rows x 47 columns]

# %% [markdown]
# These are clearly not duplicates, but let's check if maybe some are duplicates up to NAs.

# %%
keys = ['maker_id','type','sale_date','usd','auction_house']


sales = sales.sort_values(by=cols)


sales[sales['lot'].isna() & sales.duplicated(keys,keep=False)]
# they seem to be duplicates, with the pattern city missing vs city filled as above. we'll delete them and will be done deduplicating.
# Out:
#        maker_id               maker_name        type city_maker auction_house  \
# 50125      1309      Martin, Jean-Joseph  Violin Bow      Paris           NaN
# 50126      1309      Martin, Jean-Joseph  Violin Bow        NaN           NaN
# 52282       647  Sartory, Eugène Nicolas  Violin Bow        NaN           NaN
# 52298       647  Sartory, Eugène Nicolas  Violin Bow      Paris           NaN
#
#         sale_date  lot      usd           gbp      eur  ... country_iso1  \
# 50125  2024-03-22  NaN   4236.0   3474.893617   3916.0  ...           FR
# 50126  2024-03-22  NaN   4236.0   3474.893617   3916.0  ...          NaN
# 52282  2025-10-28  NaN  30270.0  22800.000000  26027.0  ...          NaN
# 52298  2025-10-28  NaN  30270.0  22800.000000  26027.0  ...           FR
#
#          admin1_name  admin2_name  candidate_count  is_ambiguous  \
# 50125  Île-de-France        Paris             59.0          True
# 50126            NaN          NaN              NaN         False
# 52282            NaN          NaN              NaN         False
# 52298  Île-de-France        Paris             59.0          True
#
#               maker_name_maker       role       date  maker_last_name  \
# 50125      Martin, Jean-Joseph  Bow maker  1837-1910           Martin
# 50126      Martin, Jean-Joseph  Bow maker  1837-1910           Martin
# 52282  Sartory, Eugène Nicolas  Bow maker  1871-1946          Sartory
# 52298  Sartory, Eugène Nicolas  Bow maker  1871-1946          Sartory
#
#        birth_cent
# 50125        19.0
# 50126        19.0
# 52282        19.0
# 52298        19.0
#
# [4 rows x 47 columns]

# %%
sales[sales['lot'].isna() & sales.duplicated(keys,keep='first')]
# Out:
#        maker_id               maker_name        type city_maker auction_house  \
# 50126      1309      Martin, Jean-Joseph  Violin Bow        NaN           NaN
# 52298       647  Sartory, Eugène Nicolas  Violin Bow      Paris           NaN
#
#         sale_date  lot      usd           gbp      eur  ... country_iso1  \
# 50126  2024-03-22  NaN   4236.0   3474.893617   3916.0  ...          NaN
# 52298  2025-10-28  NaN  30270.0  22800.000000  26027.0  ...           FR
#
#          admin1_name  admin2_name  candidate_count  is_ambiguous  \
# 50126            NaN          NaN              NaN         False
# 52298  Île-de-France        Paris             59.0          True
#
#               maker_name_maker       role       date  maker_last_name  \
# 50126      Martin, Jean-Joseph  Bow maker  1837-1910           Martin
# 52298  Sartory, Eugène Nicolas  Bow maker  1871-1946          Sartory
#
#        birth_cent
# 50126        19.0
# 52298        19.0
#
# [2 rows x 47 columns]

# %%
sales=sales[~(sales['lot'].isna() & sales.duplicated(keys,keep='first'))]
sales['sale_date']=pd.to_datetime(sales.sale_date)
sales.to_csv('sales_dedup.csv',index=False)

# %%
sales
# Out:
#        maker_id                  maker_name        type city_maker  \
# 2           179   Forster, William II or Sr       Cello     London
# 0           561          Pollastri, Gaetano      Violin    Bologna
# 1           620     Rocca, Giuseppe Antonio      Violin      Turin
# 3           722         Stradivari, Antonio      Violin    Cremona
# 4           743      Testore, Carlo Antonio      Violin      Milan
# ...         ...                         ...         ...        ...
# 52533      1213        Prager, Gustav Adolf  Violin Bow        NaN
# 52532      1638         Kunze, Wilhelm Paul      Violin  The Hague
# 52528      7609          Hendel, Arno Erwin      Violin        NaN
# 52534        63  Bernardel, Gustave Adolphe      Violin      Paris
# 52535      6572             Gaillard, Louis      Violin  Mirecourt
#
#       auction_house  sale_date  lot           usd           gbp          eur  \
# 2         Sotheby's 1976-02-12    -   3460.000000  13460.599191          NaN
# 0         Sotheby's 1976-02-12    -   2537.000000   9868.474480          NaN
# 1         Sotheby's 1976-02-12    -   8037.000000  31263.327154          NaN
# 3         Sotheby's 1976-02-12    -  17414.000000  67737.208833          NaN
# 4         Sotheby's 1976-02-12    -  13842.000000  53842.396765          NaN
# ...             ...        ...  ...           ...           ...          ...
# 52533           NaN 2025-11-21  NaN    755.000000    577.000000   656.064134
# 52532           NaN 2025-11-21  NaN   2719.000000   2078.000000  2363.834133
# 52528           NaN 2025-11-21  NaN   2405.000000   1838.000000  2091.392233
# 52534           NaN 2025-12-05  NaN   4817.745191   3597.000000  4122.000000
# 52535           NaN 2026-02-06  NaN   1180.000000    868.000000  1001.000000
#
#        ... country_iso1     admin1_name                    admin2_name  \
# 2      ...           GB         England                 Greater London
# 0      ...           IT  Emilia-Romagna                        Bologna
# 1      ...           IT        Piedmont                         Torino
# 3      ...           IT        Lombardy           Provincia di Cremona
# 4      ...           IT        Lombardy  Città metropolitana di Milano
# ...    ...          ...             ...                            ...
# 52533  ...          NaN             NaN                            NaN
# 52532  ...           NL   South Holland              Gemeente Den Haag
# 52528  ...          NaN             NaN                            NaN
# 52534  ...           FR   Île-de-France                          Paris
# 52535  ...           FR       Grand Est                         Vosges
#
#        candidate_count  is_ambiguous            maker_name_maker  \
# 2                 34.0          True   Forster, William II or Sr
# 0                  6.0          True          Pollastri, Gaetano
# 1                 16.0          True     Rocca, Giuseppe Antonio
# 3                  5.0          True         Stradivari, Antonio
# 4                 46.0          True      Testore, Carlo Antonio
# ...                ...           ...                         ...
# 52533              NaN         False        Prager, Gustav Adolf
# 52532              2.0          True         Kunze, Wilhelm Paul
# 52528              NaN         False          Hendel, Arno Erwin
# 52534             59.0          True  Bernardel, Gustave Adolphe
# 52535              2.0          True             Gaillard, Louis
#
#                role          date  maker_last_name  birth_cent
# 2      Violin maker     1739-1808          Forster        18.0
# 0      Violin maker     1886-1960        Pollastri        19.0
# 1      Violin maker     1807-1865            Rocca        19.0
# 3      Violin maker  c. 1644-1737       Stradivari        17.0
# 4      Violin maker       c. 1765          Testore        18.0
# ...             ...           ...              ...         ...
# 52533     Bow maker     1866-1953           Prager        19.0
# 52532  Violin maker       b. 1875            Kunze        19.0
# 52528           NaN     1880-1940           Hendel        19.0
# 52534  Violin maker     1832-1904        Bernardel        19.0
# 52535           NaN  c. 1830-1860         Gaillard        19.0
#
# [52354 rows x 47 columns]

# %%
sales=sales.sort_values(by='sale_date')
sales
# data range from 1829 to basically the day we scraped the web archive
# Out:
#        maker_id                  maker_name        type city_maker  \
# 2           179   Forster, William II or Sr       Cello     London
# 0           561          Pollastri, Gaetano      Violin    Bologna
# 1           620     Rocca, Giuseppe Antonio      Violin      Turin
# 3           722         Stradivari, Antonio      Violin    Cremona
# 4           743      Testore, Carlo Antonio      Violin      Milan
# ...         ...                         ...         ...        ...
# 52533      1213        Prager, Gustav Adolf  Violin Bow        NaN
# 52532      1638         Kunze, Wilhelm Paul      Violin  The Hague
# 52528      7609          Hendel, Arno Erwin      Violin        NaN
# 52534        63  Bernardel, Gustave Adolphe      Violin      Paris
# 52535      6572             Gaillard, Louis      Violin  Mirecourt
#
#       auction_house  sale_date  lot           usd           gbp          eur  \
# 2         Sotheby's 1976-02-12    -   3460.000000  13460.599191          NaN
# 0         Sotheby's 1976-02-12    -   2537.000000   9868.474480          NaN
# 1         Sotheby's 1976-02-12    -   8037.000000  31263.327154          NaN
# 3         Sotheby's 1976-02-12    -  17414.000000  67737.208833          NaN
# 4         Sotheby's 1976-02-12    -  13842.000000  53842.396765          NaN
# ...             ...        ...  ...           ...           ...          ...
# 52533           NaN 2025-11-21  NaN    755.000000    577.000000   656.064134
# 52532           NaN 2025-11-21  NaN   2719.000000   2078.000000  2363.834133
# 52528           NaN 2025-11-21  NaN   2405.000000   1838.000000  2091.392233
# 52534           NaN 2025-12-05  NaN   4817.745191   3597.000000  4122.000000
# 52535           NaN 2026-02-06  NaN   1180.000000    868.000000  1001.000000
#
#        ... country_iso1     admin1_name                    admin2_name  \
# 2      ...           GB         England                 Greater London
# 0      ...           IT  Emilia-Romagna                        Bologna
# 1      ...           IT        Piedmont                         Torino
# 3      ...           IT        Lombardy           Provincia di Cremona
# 4      ...           IT        Lombardy  Città metropolitana di Milano
# ...    ...          ...             ...                            ...
# 52533  ...          NaN             NaN                            NaN
# 52532  ...           NL   South Holland              Gemeente Den Haag
# 52528  ...          NaN             NaN                            NaN
# 52534  ...           FR   Île-de-France                          Paris
# 52535  ...           FR       Grand Est                         Vosges
#
#        candidate_count  is_ambiguous            maker_name_maker  \
# 2                 34.0          True   Forster, William II or Sr
# 0                  6.0          True          Pollastri, Gaetano
# 1                 16.0          True     Rocca, Giuseppe Antonio
# 3                  5.0          True         Stradivari, Antonio
# 4                 46.0          True      Testore, Carlo Antonio
# ...                ...           ...                         ...
# 52533              NaN         False        Prager, Gustav Adolf
# 52532              2.0          True         Kunze, Wilhelm Paul
# 52528              NaN         False          Hendel, Arno Erwin
# 52534             59.0          True  Bernardel, Gustave Adolphe
# 52535              2.0          True             Gaillard, Louis
#
#                role          date  maker_last_name  birth_cent
# 2      Violin maker     1739-1808          Forster        18.0
# 0      Violin maker     1886-1960        Pollastri        19.0
# 1      Violin maker     1807-1865            Rocca        19.0
# 3      Violin maker  c. 1644-1737       Stradivari        17.0
# 4      Violin maker       c. 1765          Testore        18.0
# ...             ...           ...              ...         ...
# 52533     Bow maker     1866-1953           Prager        19.0
# 52532  Violin maker       b. 1875            Kunze        19.0
# 52528           NaN     1880-1940           Hendel        19.0
# 52534  Violin maker     1832-1904        Bernardel        19.0
# 52535           NaN  c. 1830-1860         Gaillard        19.0
#
# [52354 rows x 47 columns]

# %%
import matplotlib.pyplot as plt

# %%
import missingno as msno
import matplotlib.pyplot as plt

# %%
msno.matrix(sales)
plt.show()
# basically euro is missing if and only if the sale is old enough (until the 1990s, at the moment of the official existence of the euro). 
# auction_house is missing if and only if the sale is recent ; bold currency almost always there recently ; no obvious pattern for city_maker and bold_currency

# %%
sales[sales.eur.isna()]
# last time euro was na is december 1998.
# Out:
#        maker_id                     maker_name    type  city_maker  \
# 2           179      Forster, William II or Sr   Cello      London
# 0           561             Pollastri, Gaetano  Violin     Bologna
# 1           620        Rocca, Giuseppe Antonio  Violin       Turin
# 3           722            Stradivari, Antonio  Violin     Cremona
# 4           743         Testore, Carlo Antonio  Violin       Milan
# ...         ...                            ...     ...         ...
# 18282      1356                    Smith, John  Violin     Falkirk
# 18281       971                Wolff, Brothers  Violin         NaN
# 18283       893                 Moritz, Alfred  Violin         NaN
# 18278       356  Thibouville-Lamy, Jérôme Firm  Violin         NaN
# 18280      1228               Pickstone, Harry  Violin  Birmingham
#
#       auction_house  sale_date  lot      usd           gbp  eur  ...  \
# 2         Sotheby's 1976-02-12    -   3460.0  13460.599191  NaN  ...
# 0         Sotheby's 1976-02-12    -   2537.0   9868.474480  NaN  ...
# 1         Sotheby's 1976-02-12    -   8037.0  31263.327154  NaN  ...
# 3         Sotheby's 1976-02-12    -  17414.0  67737.208833  NaN  ...
# 4         Sotheby's 1976-02-12    -  13842.0  53842.396765  NaN  ...
# ...             ...        ...  ...      ...           ...  ...  ...
# 18282     Phillip's 1998-12-10   35   1629.0   1846.801389  NaN  ...
# 18281     Phillip's 1998-12-10  194    575.0    652.145833  NaN  ...
# 18283     Phillip's 1998-12-10   52    728.0    826.051389  NaN  ...
# 18278     Phillip's 1998-12-10   77    959.0   1086.909722  NaN  ...
# 18280     Phillip's 1998-12-10  229    230.0    260.858333  NaN  ...
#
#       country_iso1     admin1_name                     admin2_name  \
# 2               GB         England                  Greater London
# 0               IT  Emilia-Romagna                         Bologna
# 1               IT        Piedmont                          Torino
# 3               IT        Lombardy            Provincia di Cremona
# 4               IT        Lombardy   Città metropolitana di Milano
# ...            ...             ...                             ...
# 18282           GB        Scotland                         Falkirk
# 18281          NaN             NaN                             NaN
# 18283          NaN             NaN                             NaN
# 18278          NaN             NaN                             NaN
# 18280           GB         England  City and Borough of Birmingham
#
#        candidate_count  is_ambiguous               maker_name_maker  \
# 2                 34.0          True      Forster, William II or Sr
# 0                  6.0          True             Pollastri, Gaetano
# 1                 16.0          True        Rocca, Giuseppe Antonio
# 3                  5.0          True            Stradivari, Antonio
# 4                 46.0          True         Testore, Carlo Antonio
# ...                ...           ...                            ...
# 18282              3.0          True                    Smith, John
# 18281              NaN         False                Wolff, Brothers
# 18283              NaN         False                 Moritz, Alfred
# 18278              NaN         False  Thibouville-Lamy, Jérôme Firm
# 18280             20.0          True               Pickstone, Harry
#
#                            role          date   maker_last_name  birth_cent
# 2                  Violin maker     1739-1808           Forster        18.0
# 0                  Violin maker     1886-1960         Pollastri        19.0
# 1                  Violin maker     1807-1865             Rocca        19.0
# 3                  Violin maker  c. 1644-1737        Stradivari        17.0
# 4                  Violin maker       c. 1765           Testore        18.0
# ...                         ...           ...               ...         ...
# 18282                         –           NaN             Smith         NaN
# 18281                       NaN     1879-1900             Wolff        19.0
# 18283                       NaN       c. 1897            Moritz        19.0
# 18278  Bow maker / Violin maker     1857-1968  Thibouville-Lamy        19.0
# 18280                         –           NaN         Pickstone         NaN
#
# [18234 rows x 47 columns]

# %% [markdown]
# Cardinality of categorical values

# %%
sales[['maker_name','maker_id','type','city_maker','auction_house']].nunique()
# Out:
# maker_name       3550
# maker_id         3556
# type               14
# city_maker        721
# auction_house      28
# dtype: int64

# %% [markdown]
# There seems to be distinct makers who have the same name, which would not be entirely surprising.

# %%
# On compte le nombre d'IDs uniques par nom de fabricant
maker_counts = sales.groupby('maker_name')['maker_id'].nunique()

# On filtre ceux qui ont plus de 1 ID
multi_id_makers = maker_counts[maker_counts > 1].index.tolist()
print(f"Number of makers with multiple IDs: {len(multi_id_makers)}")
print("Namely:", multi_id_makers[:5])
# Out:
# Number of makers with multiple IDs: 4
# Namely: ['Kennedy, Alexander', 'Meisel, Friedrich August', 'Smith, Thomas', 'Smith, William']

# %% [markdown]
# The Thomas Smith of Lakewood, OH and the one of London might be genuinely different - it's one of the most frequent names in the western world. Similarly the four William Smith. A quick look at the Tarisio Website shows that the two Friedrich August Meisel have different dates.

# %%
mapping_ids = sales.groupby('maker_name')['maker_id'].unique().reset_index()

mapping_ids['nb_ids'] = mapping_ids['maker_id'].apply(len)

doublons_ids = mapping_ids[mapping_ids['nb_ids'] > 1].sort_values(by='nb_ids', ascending=False)

display(doublons_ids)
# Out:
#                     maker_name                      maker_id  nb_ids
# 2992            Smith, William  [13089, 15282, 13086, 13085]       4
# 1650        Kennedy, Alexander                 [15234, 2962]       2
# 2070  Meisel, Friedrich August                 [15325, 9716]       2
# 2991             Smith, Thomas                  [694, 13081]       2

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10, 8)) 
sns.countplot(
    data=sales, 
    y='type', 
    order=sales['type'].value_counts().index,
    palette='viridis'
)

plt.title("Distribution by Type of Instrument")
plt.xlabel("Number of sales")
plt.ylabel("") 
plt.tight_layout() 
plt.show()
# Out:
# C:\Users\Pierre\AppData\Local\Temp\ipykernel_11440\836503132.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %%
sales['usd'].describe()
# Out:
# count    5.235400e+04
# mean     1.780460e+04
# std      1.410323e+05
# min      2.400000e+01
# 25%      1.839000e+03
# 50%      4.370000e+03
# 75%      1.105250e+04
# max      1.683827e+07
# Name: usd, dtype: float64

# %% [markdown]
# The mean is four times the median - a sign of a huge kurtosis. The distribution of prices is actually so right skewed that we cannot see anything on a histogram or distplot. We'll have to take the logarithm.

# %%
sales.city_maker.value_counts()
# Out:
# city_maker
# Paris             7263
# London            6031
# Mirecourt         3965
# Markneukirchen    1898
# Cremona           1126
#                   ...
# Ancarano             1
# Morbegno             1
# Fano                 1
# Annecy               1
# Krailing             1
# Name: count, Length: 721, dtype: int64

# %%
maker_profiles=pd.read_csv("maker_profiles_ALL.csv")

# %% [markdown]
# ## Creation of a feature 'last_name'

# %%
def last_name(name):
    return name.split(",")[0]

# %%
sales["maker_last_name"]=sales["maker_name"].apply(last_name)

# %%
sales["maker_last_name"].value_counts()
#Hill & Sons is not really a maker's last name, many makers bearing different last names worked for it
# Out:
# maker_last_name
# Hill & Sons    3221
# Sartory        1247
# Bazin          1091
# Tubbs          1000
# Nürnberger      942
#                ...
# Schenk            1
# Harrild           1
# Strumphler        1
# Egan              1
# Hendel            1
# Name: count, Length: 2485, dtype: int64

# %%
sum(sales["maker_last_name"].value_counts()>1)
#1811 last names occur more than once in sales
# Out:
# 1756

# %%
sum(sales["maker_last_name"].value_counts()>2)
#1479 last names occur more than twice in sales
# Out:
# 1419

# %%
sum(sales["maker_last_name"].value_counts()>10)
#721 last names occur more than ten times in sales
# Out:
# 677

# %%
i=0
while (sales["maker_last_name"].value_counts().cumsum()<30000).iloc[i]:
    i+=1
i
#the 84 most popular last names represent over 30k sales (hence over the half of the total)
# Out:
# 105

# %%
sales["maker_name"].value_counts()
# Out:
# maker_name
# Hill & Sons, W. E. Firm          3221
# Sartory, Eugène Nicolas          1247
# Tubbs, James                      914
# Nürnberger, Albert                680
# Thibouville-Lamy, Jérôme Firm     666
#                                  ...
# Strumphler, Jan                     1
# Nehr, Pierre                        1
# Egan, Thomas                        1
# Glass, Friedrich August II          1
# Hendel, Arno Erwin                  1
# Name: count, Length: 3550, dtype: int64

# %%
maker_profiles["maker_last_name"]=maker_profiles["maker_name"].apply(last_name)

# %%
maker_profiles["maker_last_name"].value_counts()
#17 different makers were called Gagliano, a proper dynasty of makers.
# Out:
# maker_last_name
# Gagliano        17
# Hornsteiner     16
# Pfretzschner    15
# Schmidt         15
# Fischer         14
#                 ..
# Zurlini          1
# Zurschmiede      1
# Zust             1
# Zwerger          1
# Zygmuntowicz     1
# Name: count, Length: 3397, dtype: int64

# %%
sum(maker_profiles["maker_last_name"].value_counts()>10)
#10 last names had at least 10 makers with that last name
# Out:
# 10

# %% [markdown]
# The sale_date feature

# %%
sales.sale_date.hist(bins=100)
#sales year run from 1825 to 2026 but almost all sales are post 1980, perhaps we should stick to that
# Out:
# <Axes: >

# %%
sales[sales.sale_date.dt.year>1980].sale_date.hist(bins=100)
# Out:
# <Axes: >

# %% [markdown]
# Since 1984, the frequency of sales seem more or less homogenous (apart for covid in 2020)

# %%
(sales.sale_date.dt.year>1980).mean()
#98% of sales are post 1980
# Out:
# np.float64(0.9925316117202124)

# %%
mask_recent=sales.sale_date.dt.year>1985
sales_recent=sales[mask_recent]

# %%
sales[mask_recent]['usd'].describe()
# Out:
# count    4.891300e+04
# mean     1.828751e+04
# std      1.453421e+05
# min      2.400000e+01
# 25%      2.005802e+03
# 50%      4.588000e+03
# 75%      1.140800e+04
# max      1.683827e+07
# Name: usd, dtype: float64

# %% [markdown]
# ## The price feature(s) - The target

# %% [markdown]
# Given the kurtosis, we'll take the log of the price.

# %%
sales['log_usd']=sales.usd.apply(np.log)

# %%
sns.displot(data=sales,x="log_usd")
#still a little right-skewed, but fairly normally distributed

# %% [markdown]
# ## The 'type' feature

# %%
sns.boxplot(data=sales,x='log_usd',hue='type')
# Out:
# <Axes: xlabel='log_usd'>

# %%
data_bow=sales[sales.type.str.contains('Bow')]
sns.boxplot(data=data_bow,x='log_usd',hue='type')
# different types have similar price distributions
# Out:
# <Axes: xlabel='log_usd'>

# %% [markdown]
# Looks like the four types of bows have similar price distributions. Bass bows tend to be cheaper but there are much fewer occurrences of them.

# %% [markdown]
# ## Impact of the maker on the price

# %% [markdown]
# We want to visualise the distribution of prices by maker. We use Ridgeplot and display the top 10 and the bottom 10 of the makers with at least 50 sales in the data base.

# %%
counts = sales['maker_name'].value_counts()
makers_50 = counts[counts >= 50].index

medians_50 = sales[sales['maker_name'].isin(makers_50)].groupby('maker_name')['log_usd'].median().sort_values(ascending=False)

top_10 = medians_50.head(10).index.tolist()
bottom_10 = medians_50.tail(10).index.tolist()

selection_makers = top_10 + bottom_10
df_extremes = sales[sales['maker_name'].isin(selection_makers)].copy()

df_extremes['maker_name'] = pd.Categorical(df_extremes['maker_name'], categories=selection_makers, ordered=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

# Palette Spectral avec autant de couleurs que de makers
n = len(selection_makers)
palette = [cm.Spectral(i / (n - 1)) for i in range(n)]

fig, axes = plt.subplots(n, 1, figsize=(12, 12), sharex=True)

x_min = 5
x_max = df_extremes['log_usd'].max()

for i, (maker, ax, color) in enumerate(zip(selection_makers, axes, palette)):
    subset = df_extremes[df_extremes['maker_name'] == maker]['log_usd']
    
    sns.kdeplot(
        data=subset,
        ax=ax,
        fill=True,
        color=color,
        alpha=0.6,
        linewidth=1.2,
        clip=(x_min, x_max)
    )
    
    ax.set_xlim(x_min, x_max)
    ax.set_ylabel(maker, rotation=0, ha='right', va='center', fontsize=8.5)
    ax.set_yticks([])
    ax.set_xlabel('')
    
    # Supprimer les bordures sauf le bas du dernier
    for spine in ['top', 'left', 'right']:
        ax.spines[spine].set_visible(False)
    if i < n - 1:
        ax.spines['bottom'].set_visible(False)
        ax.tick_params(bottom=False)
    
    ax.grid(axis='x', linestyle='--', alpha=0.4)

axes[0].set_title(
    "Comparison of the top 10 and the bottom 10 in median price (min 50 sales)",
    fontsize=12, pad=10
)
axes[-1].set_xlabel('log_usd', fontsize=10)

plt.tight_layout(h_pad=-0.8)  # h_pad négatif = overlap entre subplots
plt.show()

# %% [markdown]
# The top 10 is clearly italian, except for one Frenchman.

# %%
# Function to label each subplot
def label(x, color, label):
    ax = plt.gca()
    # Position the label closer to the left
    ax.text(4.0, 0.2, label, fontweight="bold", color=color, ha="left", va="center")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a ridge plot using seaborn FacetGrid
g = sns.FacetGrid(sales, row="type", hue="type", aspect=15, height=0.5, palette="Spectral")

# Plot the KDE with fill
g.map(sns.kdeplot, "log_usd", clip_on=False, fill=True, alpha=0.7, linewidth=1.5)

# Add a white outline
g.map(sns.kdeplot, "log_usd", clip_on=False, color="w", lw=2)

# Add horizontal line at y=0
g.map(plt.axhline, y=0, lw=2, clip_on=False)

# Function to label each subplot
def label(x, color, label):
    ax = plt.gca()
    ax.text(0, 0.2, label, fontweight="bold", color=color, ha="left", va="center", transform=ax.transAxes)

g.map(label, "log_usd")

# Adjust subplots to overlap
g.fig.subplots_adjust(hspace=0.5)

# Remove titles and y-ticks
g.set_titles("")
g.set(yticks=[])
g.set(xlim=(0, 17))
g.set_ylabels("")
g.despine(bottom=True, left=True)

# Set overall title
g.fig.suptitle("Comparison by Instrument Type", fontsize=16)
plt.show()

# %%
sales.groupby('maker_name')['log_usd'].describe().loc['Stradivari, Antonio']
# Out:
# count    192.000000
# mean      10.563426
# std        2.735904
# min        4.700480
# 25%        7.956263
# 50%       10.645209
# 75%       12.672898
# max       16.576867
# Name: Stradivari, Antonio, dtype: float64

# %% [markdown]
# ## Evolution of prices with time

# %%
sns.scatterplot(data=sales,x='sale_date',y='log_usd')
# Out:
# <Axes: xlabel='sale_date', ylabel='log_usd'>

# %% [markdown]
# We do observe some inflation across the years, but it is much more visible at the upper limit of the hull than the lower.

# %%
sales_recent['year']=sales.sale_date.dt.year

# %%
def decade(year):
    a=(year-1986) // 10
    return f"{1986+10*a}-{1986+10*a+9}"

# %%
sales_recent=sales_recent[sales_recent["year"]<2026]
sales_recent["decade"]=sales_recent["year"].apply(decade)

# %%
sales_recent.groupby('decade')['log_usd'].describe()
# Out:
#              count      mean       std       min       25%       50%  \
# decade
# 1986-1995  11353.0  7.847164  1.299455  3.912023  6.968850  7.708860
# 1996-2005  12111.0  8.404888  1.314687  3.178054  7.484369  8.287810
# 2006-2015  13914.0  8.753623  1.370735  3.871201  7.858796  8.621373
# 2016-2025  11534.0  9.067700  1.216557  4.488636  8.227643  8.902312
#
#                 75%        max
# decade
# 1986-1995  8.566364  14.389642
# 1996-2005  9.166507  15.038185
# 2006-2015  9.575704  16.576867
# 2016-2025  9.760771  16.639165

# %% [markdown]
# There the general increase of price is visible, and regular.

# %% [markdown]
# ## Currencies and bold_currency

# %% [markdown]
# These 4 sales have actually no price whatsoever mentioned and all come from the auction_house Bongartz. A quick look at the website seems to indicate the fault comes from there and is not an artefact of scraping.

# %%
sales.bold_currency.value_counts()
# Out:
# bold_currency
# gbp    31786
# usd    16003
# eur     5330
# Name: count, dtype: int64

# %% [markdown]
# ## auction_house feature

# %%
sales.auction_house.value_counts()
# Out:
# auction_house
# Tarisio                                  12441
# Sotheby's                                11038
# Phillip's                                 6386
# Christie's                                4875
# Skinner                                   4086
# Bonhams                                   3436
# Bongartz's                                3282
# Vichy-Enchères                            2062
# Brompton's                                1705
# Ingles & Hayday                           1419
# Sotheby Parke Bernet                       283
# Millon & Associés (Gilles Chancereul)      274
# Puttick & Simpson                          208
# Dorotheum                                  207
# Guy Laurent                                174
# Gardiner-Houlgate                          162
# T2 Auctions                                153
# Ader Tajan                                 139
# da Salo Auction                            131
# Tajan                                       73
# Butterfield & Butterfield                   70
# Freeman's Auctions                          60
# J & A Beare Auctions                        16
# Kestenbaum & Co.                            14
# Claude Aguttes                              13
# Tepper Galleries                            12
# Hôtel Drouot                                12
# Christie & Manson                            9
# Casa d'Aste Babuino                          6
# Anderson Galleries Inc.                      5
# Glendining & Co.                             5
# Palais Galliera                              2
# Delorme & Collin du Bocage                   2
# Rubinacci Casa d'Aste                        2
# Drouot-Richelieu                             1
# Adam Partridge Auctioneers                   1
# Leseuil & Rambert                            1
# Neuilly St. James                            1
# Foster Auction House                         1
# Rambert Michel                               1
# Name: count, dtype: int64

# %% [markdown]
# 40 different auction houses appear, of which 9 appear a single time. The Tarisio house is obviously the most frequent. 19 of them appear more than 100 times. Sotheby Parke Bernet and Sotheby's are the two names of the same auction house at different points in time.

# %%
rare_houses= sales.auction_house.value_counts().index[-21:]

# %%
def house2(house):
    return 'Rare' if house in rare_houses else house

# %%
house2('Tajan'),house2('Tarisio')
# Out:
# ('Rare', 'Tarisio')

# %%
sales['house2']=sales['auction_house'].apply(house2)

# %%
sales['house2']=sales['auction_house'].apply(house2)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# On définit la taille de la figure pour que ce soit lisible
plt.figure(figsize=(10, 8))

# On passe 'house2' en paramètre 'y' au lieu de 'hue'
sns.boxplot(data=sales, x='log_usd', y='house2')

plt.title('Distribution of prices according to auction_house')
plt.show()

# %% [markdown]
# One big house achieved incredible results, Guy Laurent. The most represented houses - the highest on the graph - did not necessarily make the best results.

# %%
sales[sales['house2']=='Guy Laurent']['year'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Guy Laurent has 174 sales archived here, some of them feature particularly famous makers such as Jean Adam. it seems that it made sales from 1994 to 2010. In particular it didn't sell the last 15 years, where prices increased significantly, which makes the sensational prices particularly remarkable.

# %% [markdown]
# ## Dates of makers

# %%
sum(maker_profiles.date.isna())
# Out:
# 1499

# %% [markdown]
# 1500 out 5000 maker_profiles have no dates, which is a problem in a bid to exploit the era a maker lives in to evaluate his work.

# %% [markdown]
# Let's have a look at these makers which have no date.

# %%
maker_profiles[maker_profiles['date'].isna()]
# Out:
#                  maker_name  maker_id          role date info maker_last_name
# 16     Aerts, René & Marcel     15467  Violin maker  NaN  NaN           Aerts
# 18            Aguzzi, Dario     15601  Violin maker  NaN  NaN          Aguzzi
# 30          Albani, Michele      1676  Violin maker  NaN  NaN          Albani
# 33          Alberini, Guido     15592  Violin maker  NaN  NaN        Alberini
# 34      Albert, Ádám Karóly     15279  Violin maker  NaN  NaN          Albert
# ...                     ...       ...           ...  ...  ...             ...
# 4935         Zobboli, Bruno       840  Violin maker  NaN  NaN         Zobboli
# 4937         Zoephel, Willy      3072  Violin maker  NaN  NaN         Zoephel
# 4941      Zucker, Frantisek     15411             –  NaN  NaN          Zucker
# 4945        Zurlini, Nicola       842  Violin maker  NaN  NaN         Zurlini
# 4946  Zurschmiede, Christof     15425  Violin maker  NaN  NaN     Zurschmiede
#
# [1499 rows x 6 columns]

# %% [markdown]
# Those with no date all seem to have no info. And it is not an artefact of the scraping, the website genuinely gives no info about them.

# %%
ids_a_filtrer = maker_profiles.loc[maker_profiles['date'].isna(), 'maker_id'].unique()
sales_filtres = sales[sales['maker_id'].isin(ids_a_filtrer)]

# %%
sales_filtres.usd.describe()
# Out:
# count      6092.000000
# mean       4020.063534
# std        5539.998331
# min          48.000000
# 25%        1079.610666
# 50%        2419.818614
# 75%        4930.414774
# max      171524.000000
# Name: usd, dtype: float64

# %% [markdown]
# These makers, which represent almost one third of the makers' list, represent less than one eigth of the sales. But that's not quite negligible. Also they tend to sell significantly lower prices than the others.

# %%
sales.usd.describe()
# Out:
# count    5.235400e+04
# mean     1.780460e+04
# std      1.410323e+05
# min      2.400000e+01
# 25%      1.839000e+03
# 50%      4.370000e+03
# 75%      1.105250e+04
# max      1.683827e+07
# Name: usd, dtype: float64

# %%
import re

def birth_cent(date_str):
    # On gère le cas où la date est nulle ou non définie
    if not isinstance(date_str, str) or date_str.lower() == 'nan':
        return np.nan
    
    # On cherche le premier groupe de 3 ou 4 chiffres (ex: 1750, 850)
    match = re.search(r'\d{3,4}', date_str)
    
    if match:
        annee = int(match.group())
        
        # Calcul du siècle : 1750 // 100 = 17 -> 17 + 1 = 18e siècle
        # Exception pour les années pile comme 1700 qui sont encore au XVIIe
        if annee % 100 == 0:
            siecle_num = annee // 100
        else:
            siecle_num = (annee // 100) + 1
            
        return str(siecle_num)
    
    return np.nan

# %%
maker_profiles['birth_cent']=maker_profiles['date'].apply(birth_cent)

# %%
maker_profiles['birth_cent'].value_counts()
# Out:
# birth_cent
# 19    1640
# 18     811
# 20     772
# 17     201
# 16      22
# 21       3
# 2        1
# 15       1
# Name: count, dtype: int64

# %%
maker_profiles[maker_profiles['birth_cent']=='2']
#that's clearly a mistake, we'll make the century XVIIIth.
# Out:
#                          maker_name          role      date  \
# maker_id
# 6205      Ficker, Johann Gottlob II  Violin maker  178-1827
#
#                                                        info maker_last_name  \
# maker_id
# 6205      Johann Gottlob Ficker was the son and pupil of...          Ficker
#
#          birth_cent
# maker_id
# 6205              2

# %%
maker_profiles.loc[maker_profiles['birth_cent']=='2','birth_cent']='18'

# %%
maker_profiles['birth_cent'].value_counts()
# Out:
# birth_cent
# 19    1640
# 18     812
# 20     772
# 17     201
# 16      22
# 21       3
# 15       1
# Name: count, dtype: int64

# %%
def birth_cent_from_id(maker_id):
    return birth_cent(maker_profiles.loc[maker_id,'date'])

# %%
sales.birth_cent.value_counts()
# Out:
# birth_cent
# 19.0    29586
# 18.0     7628
# 20.0     7400
# 17.0     1580
# 16.0       69
# Name: count, dtype: int64

# %% [markdown]
# There is an evidence here that older centuries are more valued than newer. It's precisely because the box plot makes a mess when maker_birth_cent is numeric that I decided to make it string. Note that the makers of the XXIst and of the XVth century are not represented, because too few.

# %%
df_plot = sales.dropna(subset=['birth_cent']).copy()
df_plot['birth_cent'] = df_plot['birth_cent'].astype(int).astype(str) + 'e s.'

sns.boxplot(
    data=df_plot,
    x='log_usd',
    y='birth_cent',
    order=sorted(df_plot['birth_cent'].unique()),  # ordre chronologique
    palette='Spectral'
)
plt.xlabel('Prix (log USD)')
plt.ylabel('Siècle de naissance')
plt.title('Distribution des prix par siècle')
plt.show()
# Out:
# C:\Users\Pierre\AppData\Local\Temp\ipykernel_11440\787588986.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm

df_plot = sales.dropna(subset=['birth_cent']).copy()
df_plot['birth_cent'] = df_plot['birth_cent'].astype(int)
centuries = sorted(df_plot['birth_cent'].unique())

n = len(centuries)
palette = [cm.Spectral(i / (n - 1)) for i in range(n)]

fig, axes = plt.subplots(n, 1, figsize=(12, n * 1.2), sharex=True)

x_min = df_plot['log_usd'].min()
x_max = df_plot['log_usd'].max()

for i, (century, ax, color) in enumerate(zip(centuries, axes, palette)):
    subset = df_plot[df_plot['birth_cent'] == century]['log_usd']

    ax.hist(subset, bins=40, color=color, alpha=0.4,
            density=True, range=(x_min, x_max))
    
    sns.kdeplot(
        data=subset,
        ax=ax,
        fill=True,
        color=color,
        alpha=0.5,
        linewidth=1.5,
        clip=(x_min, x_max)
    )

    # Add median line
    median = subset.median()
    ax.axvline(median, color=color, linewidth=1.2,
               linestyle='--', alpha=0.9)

    label = f"{century}th c.  (n={len(subset):,})"
    ax.set_ylabel(label, rotation=0, ha='right',
                  va='center', fontsize=9)
    ax.set_yticks([])

    for spine in ['top', 'left', 'right']:
        ax.spines[spine].set_visible(False)
    if i < n - 1:
        ax.spines['bottom'].set_visible(False)
        ax.tick_params(bottom=False)

    ax.grid(axis='x', linestyle='--', alpha=0.3)

axes[0].set_title(
    "Price distribution (log USD) by maker's birth century",
    fontsize=13, pad=12
)
axes[-1].set_xlabel('Price (log USD)', fontsize=10)

plt.tight_layout(h_pad=-1.2)
plt.show()

# %%
maker_profiles.to_csv("maker_profiles_engineered.csv",index=False)
